# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"D:\Ultimate Programming\Data Bases\Cleaned Dataset\stroke_data.csv")

# %%
df.head(3)
# Out:
#          Age  Gender     SES  Hypertension  Heart_Disease        BMI  \
# 0  66.788137    Male  Medium             1              0  25.842521
# 1  86.393609  Female  Medium             1              1  32.531061
# 2  76.158579  Female  Medium             1              0  40.681244
#
#    Avg_Glucose  Diabetes Smoking_Status  Stroke
# 0    96.428681         1        Current       1
# 1   133.350068         0          Never       1
# 2   111.489589         0          Never       0

# %%
df['Age'] = np.ceil(df['Age']).astype(int)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for col in df.select_dtypes(include='object').columns :
    df[col] = le.fit_transform(df[col])

# %%
df.head(4)
# Out:
#    Age  Gender  SES  Hypertension  Heart_Disease        BMI  Avg_Glucose  \
# 0   67       1    2             1              0  25.842521    96.428681
# 1   87       0    2             1              1  32.531061   133.350068
# 2   77       0    2             1              0  40.681244   111.489589
# 3   73       0    1             0              1  33.003193   125.692465
#
#    Diabetes  Smoking_Status  Stroke
# 0         1               0       1
# 1         0               2       1
# 2         0               2       0
# 3         0               1       0

# %%
sns.pairplot(df)
plt.show()

# %%
x = df[['Age', 'BMI', 'Avg_Glucose']]
y = df['Stroke']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Single Layer Perception

# %%
from sklearn.linear_model import Perceptron

pr = Perceptron(alpha=0.9)
pr.fit(x_train, y_train)
# Out:
# Perceptron(alpha=0.9)

# %%
print(pr.score(x_train, y_train)*100)
print(pr.score(x_test, y_test)*100)
# Out:
# 30.312499999999996
# 29.549999999999997
