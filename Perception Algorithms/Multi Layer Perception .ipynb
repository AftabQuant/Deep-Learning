# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel(r"D:\Ultimate Programming\Data Bases\Machine Learning Datasets\Classification\Bank_Churn_Messy.xlsx", sheet_name='Account_Info')

# %%
df.head(3)
# Out:
#    CustomerId    Balance  NumOfProducts HasCrCard  Tenure IsActiveMember  \
# 0    15634602       €0.0              1       Yes       2            Yes
# 1    15634602       €0.0              1       Yes       2            Yes
# 2    15647311  €83807.86              1       Yes       1            Yes
#
#    Exited
# 0       1
# 1       1
# 2       0

# %%
x = df.iloc[:,:-1]
y = df['Exited']

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    7964
# 1    2038
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

oh = LabelEncoder()
for col in x.select_dtypes(include='object').columns:
    x[col] = oh.fit_transform(x[[col]])

# %%
df.head(2)
# Out:
#    CustomerId Balance  NumOfProducts HasCrCard  Tenure IsActiveMember  Exited
# 0    15634602    €0.0              1       Yes       2            Yes       1
# 1    15634602    €0.0              1       Yes       2            Yes       1

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
for col in x.select_dtypes(include=['int64', 'float64']).columns:
    x[col] = ss.fit_transform(x[[col]])

# %%
x.head(3)
# Out:
#    CustomerId   Balance  NumOfProducts  HasCrCard    Tenure  IsActiveMember
# 0   -0.783073 -0.958274      -0.911417   0.970248 -1.041662        0.970248
# 1   -0.783073 -0.958274      -0.911417   0.970248 -1.041662        0.970248
# 2   -0.606388  1.648805      -0.911417   0.970248 -1.387453        0.970248

# %%
print(df.isnull().sum())
# Out:
# CustomerId        0
# Balance           0
# NumOfProducts     0
# HasCrCard         0
# Tenure            0
# IsActiveMember    0
# Exited            0
# dtype: int64

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10002 entries, 0 to 10001
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerId      10002 non-null  float64
#  1   Balance         10002 non-null  float64
#  2   NumOfProducts   10002 non-null  float64
#  3   HasCrCard       10002 non-null  float64
#  4   Tenure          10002 non-null  float64
#  5   IsActiveMember  10002 non-null  float64
# dtypes: float64(6)
# memory usage: 469.0 KB

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Single Layer Perceptron

# %%
from sklearn.linear_model import Perceptron

pr = Perceptron()
pr.fit(x_train, y_train)
# Out:
# Perceptron()

# %%
print(pr.score(x_train, y_train)*100)
print(pr.score(x_test, y_test)*100)
# Out:
# 70.20372453443319
# 70.11494252873564

# %% [markdown]
# # Multi Layer Perceptron

# %%
sns.pairplot(x)
plt.show()

# %%
import tensorflow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import tensorflow
#
# ModuleNotFoundError: No module named 'tensorflow'
